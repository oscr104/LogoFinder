# %%
import os
import logofinder as lf

# %%
img = "rashford_3.jpg"
img_path = os.path.join(os.getcwd(), "data", img)

ref_img = "mutd.png"
ref_path = os.path.join(os.getcwd(), "data", ref_img)

gd_model = lf.load_gd()
# Out:
# c:\Users\Oscar\anaconda3\envs\logofinder\Lib\site-packages\torch\functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3610.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# final text_encoder_type: bert-base-uncased
# c:\Users\Oscar\anaconda3\envs\logofinder\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...

# %%
lf.find_in_image(img_path, reference_path=ref_path, gd_model=gd_model, gd_threshold=0.5)
# Out:
# c:\Users\Oscar\anaconda3\envs\logofinder\Lib\site-packages\transformers\modeling_utils.py:1126: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# c:\Users\Oscar\anaconda3\envs\logofinder\Lib\site-packages\transformers\models\bert\modeling_bert.py:439: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# ...

# %%
img = "wagner_2.jpg"
img_path = os.path.join(os.getcwd(), "data", img)

ref_img = "wagner_ref.jpg"
ref_path = os.path.join(os.getcwd(), "data", ref_img)

# %%
lf.find_in_image(img_path, reference_path=ref_path, gd_model=gd_model, gd_threshold=0.4, gd_prompt="insignia")
# Out:
# c:\Users\Oscar\anaconda3\envs\logofinder\Lib\site-packages\transformers\modeling_utils.py:1126: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# c:\Users\Oscar\anaconda3\envs\logofinder\Lib\site-packages\torch\_dynamo\eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# c:\Users\Oscar\anaconda3\envs\logofinder\Lib\site-packages\torch\utils\checkpoint.py:92: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ...

# %%
img = "wagner.jpg"
img_path = os.path.join(os.getcwd(), "data", img)

ref_img = "wagner_ref.jpg"
ref_path = os.path.join(os.getcwd(), "data", ref_img)

# %%
lf.find_in_image(img_path, reference_path=ref_path, gd_model=gd_model, gd_threshold=0.4, gd_prompt="insignia")
# Out:
# Matches found - 46/10
